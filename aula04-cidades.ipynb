# %%
import pandas as pd

# %%
import numpy as np

# %%
cidades = pd.read_excel('DUR_Municipios.xlsx')
filtrarCidades =
# Out:
#       COD_UF  UF  COD_MUNICIPIO            NOME_MUNICIPIO  COD_REG_AMPLIADA  \
# 0         11  RO        1100106             Guajará-Mirim           1100205
# 1         11  RO        1100809        Candeias do Jamari           1100205
# 2         11  RO        1100205               Porto Velho           1100205
# 3         12  AC        1200054              Assis Brasil           1100205
# 4         12  AC        1200252            Epitaciolândia           1100205
# ...      ...  ..            ...                       ...               ...
# 5565      13  AM        1304104                    Tapauá           1302603
# 5566      15  PA        1505304                 Oriximiná           1501402
# 5567      13  AM        1303809  São Gabriel da Cachoeira           1302603
# 5568      13  AM        1300409                  Barcelos           1302603
# 5569      15  PA        1500602                  Altamira           1501402
#
# ...
